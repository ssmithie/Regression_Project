# %% [markdown]
# <p style='text-align:center;font-size:30px'> $$\begin{bmatrix} B_{_{ig}} \\D_{_{ata}} \\E_{_{nergy}} \end{bmatrix} $$

# %% [markdown]
# # Beer Analysis
# Performing statistal regression methods on beer data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
brewdf= pd.read_csv('cleaned_beer.csv', index_col=0)

# %%
brewdf.hist(figsize=(12,12));

# %%
from sklearn.linear_model import LinearRegression
